# %% [markdown]
# # 🕵️ Desafio 03: O Bug da Senha Fixa do Laboratório
#
# ### 🚨 Relatório da Investigação
# O sistema de login dos computadores do laboratório de Desenvolvimento de Sistemas está preso em um comportamento inesperado: mesmo quando o aluno digita a senha correta, o sistema continua pedindo a senha infinitamente!
#
# Analise o código abaixo:

# %%
# CÓDIGO COM LOOP INFINITO
senha_correta = "2002"

while True:
    tentativa = input("Digite a senha de acesso: ")
    if tentativa == senha_correta:
        print("Acesso Permitido")
        # O desenvolvedor esqueceu do comando de saída do laço!
    else:
        print("Senha Invalida")

# %% [markdown]
# ### 🎯 Sua Missão:
# 1. Identifique por que o laço nunca encerra mesmo após a mensagem "Acesso Permitido".
# 2. Corrija o algoritmo inserindo o comando correto de quebra de fluxo na célula abaixo.

# %%
# TODO: Implemente a versão corrigida com encerramento adequado do laço
