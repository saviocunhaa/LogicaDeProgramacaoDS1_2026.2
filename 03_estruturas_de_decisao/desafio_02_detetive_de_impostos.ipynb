# %% [markdown]
# # 🕵️ Desafio 02: O Detetive de Impostos e Licenças
#
# ### 🚨 Relatório da Investigação
# A prefeitura municipal contratou a equipe de desenvolvimento para auditar o cálculo de alvarás comerciais. O código atual possui falhas lógicas que estão cobrando taxas indevidas de pequenos comerciantes!
#
# Veja o código problemático:

# %%
# CÓDIGO COM FALHA LÓGICA
faturamento = float(input("Informe o faturamento anual da empresa: "))

# Erro: a ordem das condições e os operadores estão sobrepondo as faixas!
if faturamento > 0:
    taxa = faturamento * 0.05
elif faturamento > 50000:
    taxa = faturamento * 0.10
elif faturamento > 100000:
    taxa = faturamento * 0.15
else:
    taxa = 0.0

print(f"Taxa calculada: R$ {taxa:.2f}")

# %% [markdown]
# ### 🎯 Sua Missão:
# 1. Explique por que qualquer faturamento acima de 0 cai imediatamente na primeira condição (`faturamento > 0`), impedindo que as faixas de 50.000 e 100.000 sejam atingidas.
# 2. Corrija a ordem das condições ou use operadores relacionais encadeados na célula abaixo para calcular a taxa de forma justa e correta.

# %%
# TODO: Implemente a versão corrigida do cálculo de tributos
