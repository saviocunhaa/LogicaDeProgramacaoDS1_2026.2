# %% [markdown]
# # 🕵️ Desafio 06: Análise e Auditoria de Logs Suspeitos
#
# ### 🚨 Relatório da Investigação
# O servidor do portal da escola gerou um arquivo de log durante um teste de carga. O sistema precisa varrer esse arquivo e contabilizar quantas ocorrências de falha foram registradas.
#
# Veja como o arquivo simulado pode ser gerado e analisado:

# %%
# SIMULAÇÃO DO ARQUIVO DE LOG
log_data = """2026-09-03 08:00:01 INFO Servidor iniciado
2026-09-03 08:00:15 ERROR Falha na conexao com banco de dados
2026-09-03 08:00:20 INFO Tentativa de reconexao
2026-09-03 08:00:25 FAIL Autenticacao recusada para usuario admin
2026-09-03 08:00:30 ERROR Timeout na requisicao HTTP"""

with open("servidor_teste.log", "w", encoding="utf-8") as f:
    f.write(log_data)

print("Arquivo servidor_teste.log gerado.")

# %% [markdown]
# ### 🎯 Sua Missão:
# 1. Abra o arquivo `servidor_teste.log` em modo de leitura `'r'`.
# 2. Percorra cada linha do arquivo e conte quantas vezes as palavras-chave `"ERROR"` ou `"FAIL"` aparecem.
# 3. Imprima na tela o total de incidentes críticos detectados.

# %%
# TODO: Implemente a auditoria do arquivo de log aqui
