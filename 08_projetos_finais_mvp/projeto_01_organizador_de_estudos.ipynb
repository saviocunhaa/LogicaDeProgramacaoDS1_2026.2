# %% [markdown]
# # 🚀 Projeto 01: Organizador de Estudos para Desenvolvedores (MVP)
#
# ### 📌 Descrição do Sistema
# Construa uma aplicação em modo texto (CLI) para auxiliar os alunos do curso técnico a organizarem suas metas diárias de estudo e tarefas práticas.
#
# ### 📋 Requisitos do MVP:
# 1. **Menu Principal:**
#    * 1 - Cadastrar nova meta de estudo (Disciplina, Tópico, Horas estimadas)
#    * 2 - Listar todas as metas cadastradas
#    * 3 - Salvar metas em arquivo (`cronograma_estudos.txt`)
#    * 4 - Carregar metas salvas do arquivo
#    * 0 - Sair do sistema
# 2. **Modularização:** O código deve conter funções específicas para cada operação do menu.
# 3. **Validação:** Não permitir cadastro de horas negativas ou zero.

# %%
# TODO: Desenvolva o MVP 01 completo abaixo
# Estruture suas funções:
# def cadastrar_meta(...):
# def listar_metas(...):
# def salvar_arquivo(...):
# def carregar_arquivo(...):

# Loop principal do menu
