# %% [markdown]
# # 🚀 Projeto 02: Controle de Notas e Gastos da Turma (MVP)
#
# ### 📌 Descrição do Sistema
# Desenvolva um sistema para a gestão da comissão de formatura e acompanhamento de rendimento da turma de Desenvolvimento de Sistemas.
#
# ### 📋 Requisitos do MVP:
# 1. **Módulo Financeiro:**
#    * Registrar entradas de arrecadação (mensalidades de formatura, eventos).
#    * Registrar despesas (gastos com eventos e materiais).
#    * Exibir o saldo atualizado.
# 2. **Módulo Acadêmico:**
#    * Cadastrar alunos e suas médias finais.
#    * Exibir a média geral da turma e a taxa de aprovação.
# 3. **Persistência:** Gravar o relatório financeiro consolidado em um arquivo `balanco_turma.txt`.

# %%
# TODO: Desenvolva o MVP 02 completo abaixo
