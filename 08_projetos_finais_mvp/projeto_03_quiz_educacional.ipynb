# %% [markdown]
# # 🚀 Projeto 03: Quiz Educacional Interativo com Ranking (MVP)
#
# ### 📌 Descrição do Sistema
# Crie um jogo interativo de perguntas e respostas sobre Lógica de Programação e Python para testar os conhecimentos dos estudantes da escola.
#
# ### 📋 Requisitos do MVP:
# 1. **Banco de Questões:** Utilize uma lista de dicionários para armazenar pelo menos 5 perguntas de múltipla escolha com suas alternativas e a resposta correta.
# 2. **Mecânica do Jogo:**
#    * Solicitar o nome do jogador.
#    * Apresentar uma pergunta por vez e ler a alternativa escolhida.
#    * Contabilizar e acumular a pontuação a cada acerto.
# 3. **Ranking Persistente:** Ao final da partida, gravar o nome do jogador e sua pontuação final em um arquivo `ranking_jogadores.txt`.
# 4. **Exibição do Placar:** Opção no menu para ler e exibir os 5 melhores jogadores salvos no arquivo.

# %%
# TODO: Desenvolva o MVP 03 completo abaixo
