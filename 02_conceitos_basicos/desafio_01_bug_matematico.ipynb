# %% [markdown]
# # 🕵️ Desafio 01: O Bug Matemático da Média Escolar
#
# ### 🚨 Relatório da Ocorrência
# Um estagiário do sistema acadêmico da escola tentou implementar o cálculo da média semestral de um aluno e o cálculo do valor da mensalidade com desconto, mas o sistema apresentou resultados bizarros!
#
# Observe o código com defeito abaixo:

# %%
# CÓDIGO COM BUG (Analise o erro)
nota1 = input("Digite a primeira nota: ")
nota2 = input("Digite a segunda nota: ")

# O estagiário tentou calcular a média assim:
media = nota1 + nota2 / 2

print("A média do aluno é:", media)

# %% [markdown]
# ### 🎯 Sua Missão de Detetive:
# 1. Identifique os **dois erros graves** presentes no código acima:
#    - Erro de tipagem (falta de *casting*).
#    - Erro de precedência de operadores na fórmula da média.
# 2. Na célula abaixo, reescreva o algoritmo corrigido, garantindo que o usuário consiga digitar as notas em formato decimal e a média seja calculada corretamente.

# %%
# TODO: Escreva aqui a sua versão corrigida e testada
# Lembre-se: use float(input(...)) e parênteses para forçar a soma antes da divisão!
