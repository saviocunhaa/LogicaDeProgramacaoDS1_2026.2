# %% [markdown]
# # 🕵️ Desafio 05: O Inventário Suspeito do Laboratório
#
# ### 🚨 Relatório da Investigação
# O inventário de peças e componentes do laboratório de informática foi manipulado por um script corrompido que duplicou registros e tentou alterar chaves inexistentes em um dicionário.
#
# Analise o código suspeito:

# %%
# CÓDIGO COM ERRO DE DICIONÁRIO E DUPLICATAS
itens_recebidos = ["Mouse USB", "Teclado ABNT2", "Cabo HDMI", "Mouse USB", "Cabo HDMI"]

# O analista precisa eliminar os itens duplicados e registrar as quantidades
estoque = {
    "Mouse USB": 10,
    "Teclado ABNT2": 8
}

# Tentativa com erro de chave inexistente:
# print(estoque["Cabo HDMI"]) # Isso gera KeyError!

# %% [markdown]
# ### 🎯 Sua Missão:
# 1. Converta a lista `itens_recebidos` em um `set` para descobrir a lista de itens únicos sem duplicatas.
# 2. Utilize o método seguro `.get("chave", valor_padrao)` no dicionário para evitar o erro `KeyError` ao consultar itens que ainda não foram cadastrados.

# %%
# TODO: Escreva a resolução do inventário seguro aqui
