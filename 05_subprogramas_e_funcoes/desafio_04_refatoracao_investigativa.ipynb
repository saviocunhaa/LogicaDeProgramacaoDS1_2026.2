# %% [markdown]
# # 🕵️ Desafio 04: Refatoração Investigativa de Código Monolítico
#
# ### 🚨 Relatório da Investigação
# Recebemos um código antigo de controle de estoque que foi escrito em um único bloco gigante e confuso ("código espaguete"). O código calcula descontos, formata saídas e soma impostos tudo misturado.
#
# Veja o código desorganizado:

# %%
# CÓDIGO MONOLÍTICO PARA REFATORAR
p1 = 150.0
d1 = p1 * 0.10
vf1 = p1 - d1
imp1 = vf1 * 0.05
total1 = vf1 + imp1
print(f"Item 1 -> Final: R$ {total1:.2f}")

p2 = 300.0
d2 = p2 * 0.10
vf2 = p2 - d2
imp2 = vf2 * 0.05
total2 = vf2 + imp2
print(f"Item 2 -> Final: R$ {total2:.2f}")

# %% [markdown]
# ### 🎯 Sua Missão:
# 1. Decomponha esse processo repetitivo criando uma função chamada `calcular_preco_final(preco_base, taxa_desconto, taxa_imposto)` que receba os valores e retorne o preço calculado.
# 2. Crie uma função auxiliar `exibir_relatorio_item(numero_item, preco_final)` para imprimir o resultado formatado.
# 3. Teste suas novas funções com diferentes valores na célula abaixo.

# %%
# TODO: Escreva suas funções refatoradas e faça a chamada limpa aqui
